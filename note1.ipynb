# %%
import polars as pl

# %%
# 1
# Shift-JISのCSVファイルを読み込む
data = pl.read_csv("input/chapter-1/data/22_shizuoka_all_20210331.csv")
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[2], line 3
#       1 # 1
#       2 # Shift-JISのCSVファイルを読み込む
# ----> 3 data = pl.read_csv("input/chapter-1/data/22_shizuoka_all_20210331.csv")
#
# File ~/PycharmProjects/polars_practice/venv/lib/python3.10/site-packages/polars/io.py:377, in read_csv(file, has_header, columns, new_columns, sep, comment_char, quote_char, skip_rows, dtypes, null_values, missing_utf8_is_empty_string, ignore_errors, parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_count_name, row_count_offset, sample_size, eol_char)
#     369         dtypes = {
#     370             new_to_current.get(column_name, column_name): column_dtype
#     371             for column_name, column_dtype in dtypes.items()
#     372         }
# ...

# %%
data = pl.read_csv("input/chapter-1/data/22_shizuoka_all_20210331.csv", encoding="cp932", has_header=False)
len(data)
# Out:
# 114613

# %%
data.head(3)
# Out:
# shape: (3, 30)
# ┌──────────┬───────────┬──────────┬──────────┬─────┬───────────┬───────────┬───────────┬───────────┐
# │ column_1 ┆ column_2  ┆ column_3 ┆ column_4 ┆ ... ┆ column_27 ┆ column_28 ┆ column_29 ┆ column_30 │
# │ ---      ┆ ---       ┆ ---      ┆ ---      ┆     ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ i64      ┆ i64       ┆ i64      ┆ i64      ┆     ┆ str       ┆ str       ┆ str       ┆ i64       │
# ╞══════════╪═══════════╪══════════╪══════════╪═════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 100001304 ┆ 1        ┆ 1        ┆ ... ┆ 1-20,     ┆ null      ┆ シズオカ  ┆ 0         │
# │          ┆ 0008      ┆          ┆          ┆     ┆ Jonaicho, ┆           ┆ カテイサ  ┆           │
# │          ┆           ┆          ┆          ┆     ┆ Aoi ku,   ┆           ┆ イバンシ  ┆           │
# │          ┆           ┆          ┆          ┆     ┆ Shizuoka. ┆           ┆ ョ        ┆           │
# ...

# %%
# 2
len(data.columns)
# Out:
# 30

# %%
data.dtypes
# Out:
# [Int64,
#  Int64,
#  Int64,
#  Int64,
#  Utf8,
#  Utf8,
#  Utf8,
#  Utf8,
#  Int64,
#  Utf8,
#  Utf8,
#  Utf8,
#  Utf8,
#  Int64,
#  Int64,
#  Int64,
#  Utf8,
#  Utf8,
#  Utf8,
#  Int64,
#  Int64,
#  Utf8,
#  Utf8,
#  Int64,
#  Utf8,
#  Utf8,
#  Utf8,
#  Utf8,
#  Utf8,
#  Int64]

# %%
data
# Out:
# shape: (114613, 30)
# ┌──────────┬───────────┬──────────┬──────────┬─────┬───────────┬───────────┬───────────┬───────────┐
# │ column_1 ┆ column_2  ┆ column_3 ┆ column_4 ┆ ... ┆ column_27 ┆ column_28 ┆ column_29 ┆ column_30 │
# │ ---      ┆ ---       ┆ ---      ┆ ---      ┆     ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ i64      ┆ i64       ┆ i64      ┆ i64      ┆     ┆ str       ┆ str       ┆ str       ┆ i64       │
# ╞══════════╪═══════════╪══════════╪══════════╪═════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1        ┆ 100001304 ┆ 1        ┆ 1        ┆ ... ┆ 1-20,     ┆ null      ┆ シズオカ  ┆ 0         │
# │          ┆ 0008      ┆          ┆          ┆     ┆ Jonaicho, ┆           ┆ カテイサ  ┆           │
# │          ┆           ┆          ┆          ┆     ┆ Aoi ku,   ┆           ┆ イバンシ  ┆           │
# │          ┆           ┆          ┆          ┆     ┆ Shizuoka. ┆           ┆ ョ        ┆           │
# ...

# %%
# 3
mst = pl.read_csv("input/chapter-1/data/mst_column_name.txt", encoding="shift-jis", sep="\t")

# %%
mst
# Out:
# shape: (30, 3)
# ┌───────────┬────────────────────────────────────────────┬──────────────────┐
# │ column_id ┆ column_name_ja                             ┆ column_name_en   │
# │ ---       ┆ ---                                        ┆ ---              │
# │ i64       ┆ str                                        ┆ str              │
# ╞═══════════╪════════════════════════════════════════════╪══════════════════╡
# │ 1         ┆ 一連番号                                   ┆ sequenceNumber   │
# │ 2         ┆ 法人番号                                   ┆ corporateNumber  │
# │ 3         ┆ 処理区分                                   ┆ process          │
# │ 4         ┆ 訂正区分                                   ┆ correct          │
# │ ...       ┆ ...                                        ┆ ...              │
# │ 27        ┆ 国内所在地（市町村丁目番地等）（英語表記） ┆ enCityName       │
# │ 28        ┆ 国外所在地（英語表記）                     ┆ enAddressOutside │
# ...

# %%
# 4
data.columns = mst["column_name_en"]

# %%
data
# Out:
# shape: (114613, 30)
# ┌────────────┬────────────┬─────────┬─────────┬─────┬──────────┬────────────┬────────────┬─────────┐
# │ sequenceNu ┆ corporateN ┆ process ┆ correct ┆ ... ┆ enCityNa ┆ enAddressO ┆ furigana   ┆ hihyoji │
# │ mber       ┆ umber      ┆ ---     ┆ ---     ┆     ┆ me       ┆ utside     ┆ ---        ┆ ---     │
# │ ---        ┆ ---        ┆ i64     ┆ i64     ┆     ┆ ---      ┆ ---        ┆ str        ┆ i64     │
# │ i64        ┆ i64        ┆         ┆         ┆     ┆ str      ┆ str        ┆            ┆         │
# ╞════════════╪════════════╪═════════╪═════════╪═════╪══════════╪════════════╪════════════╪═════════╡
# │ 1          ┆ 1000013040 ┆ 1       ┆ 1       ┆ ... ┆ 1-20,    ┆ null       ┆ シズオカカ ┆ 0       │
# │            ┆ 008        ┆         ┆         ┆     ┆ Jonaicho ┆            ┆ テイサイバ ┆         │
# │            ┆            ┆         ┆         ┆     ┆ , Aoi    ┆            ┆ ンショ     ┆         │
# ...

# %%
# 5
data.describe()
# Out:
# shape: (7, 31)
# ┌───────────┬────────────┬────────────┬──────────┬─────┬──────────┬────────────┬────────┬──────────┐
# │ describe  ┆ sequenceNu ┆ corporateN ┆ process  ┆ ... ┆ enCityNa ┆ enAddressO ┆ furiga ┆ hihyoji  │
# │ ---       ┆ mber       ┆ umber      ┆ ---      ┆     ┆ me       ┆ utside     ┆ na     ┆ ---      │
# │ str       ┆ ---        ┆ ---        ┆ f64      ┆     ┆ ---      ┆ ---        ┆ ---    ┆ f64      │
# │           ┆ f64        ┆ f64        ┆          ┆     ┆ str      ┆ str        ┆ str    ┆          │
# ╞═══════════╪════════════╪════════════╪══════════╪═════╪══════════╪════════════╪════════╪══════════╡
# │ count     ┆ 114613.0   ┆ 114613.0   ┆ 114613.0 ┆ ... ┆ 114613   ┆ 114613     ┆ 114613 ┆ 114613.0 │
# │ null_coun ┆ 0.0        ┆ 0.0        ┆ 0.0      ┆ ... ┆ 114383   ┆ 114613     ┆ 67993  ┆ 0.0      │
# │ t         ┆            ┆            ┆          ┆     ┆          ┆            ┆        ┆          │
# ...

# %%
data.null_count()
# Out:
# shape: (1, 30)
# ┌────────────┬────────────┬─────────┬─────────┬─────┬────────────┬────────────┬──────────┬─────────┐
# │ sequenceNu ┆ corporateN ┆ process ┆ correct ┆ ... ┆ enCityName ┆ enAddressO ┆ furigana ┆ hihyoji │
# │ mber       ┆ umber      ┆ ---     ┆ ---     ┆     ┆ ---        ┆ utside     ┆ ---      ┆ ---     │
# │ ---        ┆ ---        ┆ u32     ┆ u32     ┆     ┆ u32        ┆ ---        ┆ u32      ┆ u32     │
# │ u32        ┆ u32        ┆         ┆         ┆     ┆            ┆ u32        ┆          ┆         │
# ╞════════════╪════════════╪═════════╪═════════╪═════╪════════════╪════════════╪══════════╪═════════╡
# │ 0          ┆ 0          ┆ 0       ┆ 0       ┆ ... ┆ 114383     ┆ 114613     ┆ 67993    ┆ 0       │
# └────────────┴────────────┴─────────┴─────────┴─────┴────────────┴────────────┴──────────┴─────────┘
